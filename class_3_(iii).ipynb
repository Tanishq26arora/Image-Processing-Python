# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open('C:/Users/tanis/Downloads/scenery 2.jpeg')
img_arr=np.array(img)
plt.imshow(img_arr)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open('C:/Users/tanis/Downloads/scenery 2.jpeg')
img_arr=np.array(img)
img_arr[0:90,0:140,(0,2)]=0
img_arr[0:90,140:,(1,2)]=0
img_arr[90:,0:140,0]=0
img_arr[90:,140:,1]=0
plt.imshow(img_arr)
