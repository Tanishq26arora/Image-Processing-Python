# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open('C:/Users/tanis/Downloads/scenery 1.jpeg')
img_arr=np.array(img)
plt.imshow(img_arr)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open('C:/Users/tanis/Downloads/scenery 1.jpeg')
img_arr=np.array(img)
img_arr[0:80,0:150,1]=0
img_arr[80:,0:150,2]=0
img_arr[0:80,150:,(2,1)]=0
img_arr[80:,150:,(0,2)]=0
plt.imshow(img_arr)
